# %% [markdown]
# run using w2p27 kernel

# %% [markdown]
# # OrNV Transmission Experiment
#
# ## Methods
#
# ## Results
#
# ## Analysis

# %%
# %matplotlib notebook
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import lifelines
from lifelines import KaplanMeierFitter, statistics
import numpy as np
import re

# %%
df = pd.read_csv('ornv-transmission.csv', parse_dates=[3,4])
#print df.info()

# %%
# Create some extra columns
# t is time until death in days after start of bioassay
# e is a boolean indication that the beetle died during the bioassay

df['date_end_bioassay'] = df.date_died.max()
t, e = lifelines.utils.datetimes_to_durations(
    start_times=pd.to_datetime(df.date_treated),
    end_times=pd.to_datetime(df.date_died),
    fill_date=pd.to_datetime(df.date_end_bioassay))
df['t'] = t
df['e'] = e
df
# Out:
#    jar_id sex  treatment date_treated  date_died date_end_bioassay     t  \
# 0      C1   m       none   2019-12-26 2020-01-16        2020-02-06  21.0
# 1      C2   m       none   2019-12-26 2020-01-29        2020-02-06  34.0
# 2      C3   m       none   2019-12-26 2020-01-19        2020-02-06  24.0
# 3      C4   m       none   2019-12-26 2020-01-21        2020-02-06  26.0
# 4      C5   m       none   2019-12-26 2020-01-29        2020-02-06  34.0
# 5      C6   m       none   2019-12-27        NaT        2020-02-06  41.0
# 6      C7   m       none   2019-12-27 2020-01-02        2020-02-06   6.0
# 7      C8   m       none   2019-12-27 2020-01-23        2020-02-06  27.0
# 8      C9   m       none   2019-12-27 2020-01-25        2020-02-06  29.0
# 9     C10   m       none   2019-12-27        NaT        2020-02-06  41.0
# 10    C11   m       none   2019-12-27 2020-01-25        2020-02-06  29.0
# 11    C12   m       none   2019-12-27        NaT        2020-02-06  41.0
# 12    C13   m       none   2019-12-27        NaT        2020-02-06  41.0
# 13    C14   m       none   2019-12-27        NaT        2020-02-06  41.0
# 14    C15   m       none   2019-12-27        NaT        2020-02-06  41.0
# 15     C1   f       none   2019-12-26 2020-01-29        2020-02-06  34.0
# 16     C2   f       none   2019-12-26        NaT        2020-02-06  42.0
# 17     C3   f       none   2019-12-26 2020-01-29        2020-02-06  34.0
# 18     C4   f       none   2019-12-26 2020-01-31        2020-02-06  36.0
# 19     C5   f       none   2019-12-26        NaT        2020-02-06  42.0
# 20     C6   f       none   2019-12-27 2020-01-16        2020-02-06  20.0
# 21     C7   f       none   2019-12-27 2020-01-02        2020-02-06   6.0
# 22     C8   f       none   2019-12-27 2020-01-23        2020-02-06  27.0
# 23     C9   f       none   2019-12-27        NaT        2020-02-06  41.0
# 24    C10   f       none   2019-12-27 2020-01-19        2020-02-06  23.0
# 25    C11   f       none   2019-12-27        NaT        2020-02-06  41.0
# 26    C12   f       none   2019-12-27 2020-01-21        2020-02-06  25.0
# 27    C13   f       none   2019-12-27        NaT        2020-02-06  41.0
# 28    C14   f       none   2019-12-27        NaT        2020-02-06  41.0
# 29    C15   f       none   2019-12-27        NaT        2020-02-06  41.0
# ..    ...  ..        ...          ...        ...               ...   ...
# 60    TM1   m      virus   2019-12-26 2020-01-02        2020-02-06   7.0
# 61    TM2   m      virus   2019-12-26        NaT        2020-02-06  42.0
# 62    TM3   m      virus   2019-12-26 2020-01-19        2020-02-06  24.0
# 63    TM4   m      virus   2019-12-26 2020-01-31        2020-02-06  36.0
# 64    TM5   m      virus   2019-12-26        NaT        2020-02-06  42.0
# 65    TM6   m      virus   2019-12-27 2020-01-29        2020-02-06  33.0
# 66    TM7   m      virus   2019-12-27        NaT        2020-02-06  41.0
# 67    TM8   m      virus   2019-12-27 2020-01-19        2020-02-06  23.0
# 68    TM9   m      virus   2019-12-27        NaT        2020-02-06  41.0
# 69   TM10   m      virus   2019-12-27 2020-01-08        2020-02-06  12.0
# 70   TM11   m      virus   2019-12-27 2020-01-14        2020-02-06  18.0
# 71   TM12   m      virus   2019-12-27 2020-01-19        2020-02-06  23.0
# 72   TM13   m      virus   2019-12-27 2020-01-29        2020-02-06  33.0
# 73   TM14   m      virus   2019-12-27 2020-01-29        2020-02-06  33.0
# 74   TM15   m      virus   2019-12-27        NaT        2020-02-06  41.0
# 75    TM1   f  companion   2019-12-26        NaT        2020-02-06  42.0
# 76    TM2   f  companion   2019-12-26 2020-01-27        2020-02-06  32.0
# 77    TM3   f  companion   2019-12-26 2020-02-06        2020-02-06  42.0
# 78    TM4   f  companion   2019-12-26        NaT        2020-02-06  42.0
# 79    TM5   f  companion   2019-12-26 2020-01-19        2020-02-06  24.0
# 80    TM6   f  companion   2019-12-27 2020-01-25        2020-02-06  29.0
# 81    TM7   f  companion   2019-12-27 2020-01-29        2020-02-06  33.0
# 82    TM8   f  companion   2019-12-27 2020-02-06        2020-02-06  41.0
# 83    TM9   f  companion   2019-12-27 2020-01-08        2020-02-06  12.0
# 84   TM10   f  companion   2019-12-27 2020-01-14        2020-02-06  18.0
# 85   TM11   f  companion   2019-12-27 2020-01-29        2020-02-06  33.0
# 86   TM12   f  companion   2019-12-27        NaT        2020-02-06  41.0
# 87   TM13   f  companion   2019-12-27 2020-02-03        2020-02-06  38.0
# 88   TM14   f  companion   2019-12-27 2020-01-14        2020-02-06  18.0
# 89   TM15   f  companion   2019-12-27 2020-01-19        2020-02-06  23.0
#
#         e
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# 5   False
# 6    True
# 7    True
# 8    True
# 9   False
# 10   True
# 11  False
# 12  False
# 13  False
# 14  False
# 15   True
# 16  False
# 17   True
# 18   True
# 19  False
# 20   True
# 21   True
# 22   True
# 23  False
# 24   True
# 25  False
# 26   True
# 27  False
# 28  False
# 29  False
# ..    ...
# 60   True
# 61  False
# 62   True
# 63   True
# 64  False
# 65   True
# 66  False
# 67   True
# 68  False
# 69   True
# 70   True
# 71   True
# 72   True
# 73   True
# 74  False
# 75  False
# 76   True
# 77   True
# 78  False
# 79   True
# 80   True
# 81   True
# 82   True
# 83   True
# 84   True
# 85   True
# 86  False
# 87   True
# 88   True
# 89   True
#
# [90 rows x 8 columns]

# %%
sns.set()

# Create custom palette
colors = ["#00FF00", "#000000","#FF0000", ]
sns.set_palette(sns.color_palette(colors))

# Create survorship plot

fig, ax = plt.subplots(figsize=(8,6))
kmf = KaplanMeierFitter()
for name, grouped_df in df.groupby('treatment'):
    kmf.fit(grouped_df['t'], grouped_df['e'], label=name)
    kmf.plot(ax=ax, linewidth=5, ci_show=False)
ax.set_xlabel('days after treatment')
ax.set_ylabel('proportion dead')
ax.set_ylim([0,1])
ax.set_title('Survivorship');
#fig.savefig('survivorshipfig.pdf')
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
tgroup = 'TF'

# Copy the slice where jar_id starts with 'TF'
dftf = df[df.jar_id.str.startswith(tgroup)].copy()

# Filter out beetles which did not die
dftf = dftf[dftf.e]

# Create 'pair_id' column
dftf['pair_id'] = dftf.apply(lambda row: int(re.findall('\d+',row.jar_id)[0]), axis=1)

# Sort so that virus treatments come first
dftf.sort_values(by='treatment', inplace=True, ascending=False)

sns.set()

# Create custom palette
colors = ["#FF0000", "#00FF00"]
sns.set_palette(sns.color_palette(colors))

p = sns.lmplot(x='t', y='pair_id', data=dftf, hue='treatment', fit_reg=False, y_jitter=0.2)
p = p.set(xlim=(0,42))
p = p.set(ylim=(0,16))
p = p.set(yticks=np.arange(1,16,1))
p = p.set(xticks=np.arange(0,42,4))
plt.title('Females dosed with virus');
# Out:
# <img src="data:image/png;base64,..." width="639">

# %%
tgroup = 'TM'

# Copy the slice where jar_id starts with 'TF'
dftf = df[df.jar_id.str.startswith(tgroup)].copy()

# Filter out beetles which did not die
dftf = dftf[dftf.e]

# Create 'pair_id' column
dftf['pair_id'] = dftf.apply(lambda row: int(re.findall('\d+',row.jar_id)[0]), axis=1)

# Sort so that virus treatments come first
dftf.sort_values(by='treatment', inplace=True, ascending=False)

sns.set()

# Create custom palette
colors = ["#FF0000", "#00FF00"]
sns.set_palette(sns.color_palette(colors))

p=sns.lmplot(x='t', y='pair_id', data=dftf, hue='treatment', fit_reg=False, y_jitter=0.2)
p = p.set(xlim=(0,42))
p = p.set(ylim=(0,16))
p = p.set(yticks=np.arange(1,16,1))
p = p.set(xticks=np.arange(0,42,4))
plt.title('Males dosed with virus');
# Out:
# <img src="data:image/png;base64,..." width="639">
